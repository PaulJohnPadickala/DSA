# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading Dataset

# %%
data1 = pd.read_excel(r'C:\Users\paulj\OneDrive\Desktop\COding\DSA\Assignment 1\iris.xls')

# %% [markdown]
# ### Displaying Columns

# %%
print(data1.columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# ### Mean of each column

# %%
print(data1.mean())
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# C:\Users\paulj\AppData\Local\Temp\ipykernel_17808\2132071385.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(data1.mean())

# %% [markdown]
# ### Null Values

# %%
print(data1.isnull().sum())
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(data1)
plt.show()

# %% [markdown]
# ### Scatterplot

# %%
sns.scatterplot(data1)
plt.show()

# %% [markdown]
# ### Heatmap

# %%
corr_matrix = data1.corr()
sns.heatmap(corr_matrix)
# Out:
# C:\Users\paulj\AppData\Local\Temp\ipykernel_17808\3192262194.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data1.corr()
# <Axes: >
